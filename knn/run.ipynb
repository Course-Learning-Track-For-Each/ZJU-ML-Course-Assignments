# %% [markdown]
# # K-Nearest Neighbor
# *Complete and hand in this completed worksheet (including its outputs and any supporting code outside of the worksheet) with your assignment submission. Please check the pdf file for more details.*
#
# In this exercise you will:
#
# - implement the **K-Nearest Neighbor** algorithm
# - play with the hyperparameter K
# - try KNN on **real-world data**, i.e. the CAPTCHA of a website in ZJU
#
# Please note that **YOU CANNOT USE ANY MACHINE LEARNING PACKAGE SUCH AS SKLEARN** for any homework, unless you are asked.

# %%
# some basic imports
import scipy.io as sio
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib inline
# %matplotlib notebook


# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# ### KNN experiment with hyperparameter K

# %%
from mkdata import mkdata
from knn_plot import knn_plot

[X, y] = mkdata()

K = [1, 10, 100]
for k in K:
    knn_plot(X, y, k)

# %% [markdown]
# ### Now Let's hack the website http://cwcx.zju.edu.cn/WFManager/login.jsp

# %%
from hack import hack
from extract_image import extract_image
from show_image import show_image
import os

# %%
test_img = './test_data/1.jpg'  # change it yourself
x = extract_image(test_img)
show_image(x)

# %%
# 进行数据集的标注
path = "train_data/"
img_list = os.listdir(path)
x_train = y_train = []
for single_img in img_list:
    x = extract_image(path + single_img)
    x = x.tolist()
    for i in range(len(x)):
        if single_img[i] >= '0' and single_img[i] <= '9':
            x_train.append(x[i])
            y_train.append(int((single_img[i])))
x_train = np.array(x_train, dtype=object)
y_train = np.array(y_train, dtype=object)
np.savez("hack_data2.npz", x_train = x_train, y_train = y_train)

# %%
res = hack(test_img)
res_in_int = [int(x[0]) for x in res]
print("The hack result is:", res_in_int)
# Out:
# The hack result is: [4, 5, 8, 8]
