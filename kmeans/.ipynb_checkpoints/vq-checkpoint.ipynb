# %% [markdown]
# # K-Means and VQ
# *Complete and hand in this completed worksheet (including its outputs and any supporting code outside of the worksheet) with your assignment submission. Please check the pdf file for more details.*
#
# In this exercise you will:
#
# - implement the **K-Means clustering** algorithm
# - play with the hyperparameter K
# - implement the Vector Quantization with K-Means
#
# Please note that **YOU CANNOT USE ANY MACHINE LEARNING PACKAGE SUCH AS SKLEARN** for any homework, unless you are asked.

# %%
# some basic imports
import scipy.io as sio
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib inline

# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# Run your k-means algorithm on `kmeans_data.mat`. Note that the lines indicate the iterations of centroids.

# %%
from kmeans import kmeans
from kmeans_plot import kmeans_plot
x = sio.loadmat('kmeans_data.mat')['X']
k = 2  # modify if you want
idx, ctrs, iter_ctrs = kmeans(x, k)
kmeans_plot(x, idx, ctrs, iter_ctrs)
print("最后确定的中心点的位置：")
print(ctrs)
print("若干次迭代过程中中心点位置移动的轨迹：")
# Out:
# 最后确定的中心点的位置：
# [[0.60790781 1.16659722]
#  [3.51257908 1.25157237]]
# 若干次迭代过程中中心点位置移动的轨迹：

# %% [markdown]
# Run your k-means algorithm on the digit dataset `digit_data.mat`.

# %%
from show_digit import show_digit
x = sio.loadmat('digit_data.mat')['X']
for k in [10, 20, 50]:
    _, ctrs, _ = kmeans(x, k)
    show_digit(ctrs)

# %% [markdown]
# # Vector quantization
# Compress images with K set to 8, 16, 32 and 64.

# %%
import kmeans
from matplotlib.pyplot import imread
img = imread('sample1.jpg')
fea = img.reshape((img.shape[0]*img.shape[1], 3)).astype(np.float64)
# YOUR (SEVERAL LINES) CODE HERE
# begin answer
print("原图片：")
plt.imshow(fea.reshape(img.shape).astype(np.uint8))
plt.show()
print("进行K聚类以后：")
print(img.shape)
# 利用Kmeans对图片进行压缩的基本思路是：找到K个中心点
# 用中心点的颜色来代表该类里面所有的颜色，这样就减小了图片的存储空间
for k in [1, 2, 4, 8]:
    print("k = " + str(k) + "时候的压缩情况")
    idx, cters, _ = kmeans.kmeans(fea.copy(), k)
    new_img = cters[idx]
    plt.imshow(new_img.reshape(img.shape).astype(np.uint8))
    plt.show()
# end answer
# Out:
# 原图片：
# 进行K聚类以后：
# (800, 1062, 3)
# k = 1时候的压缩情况
# k = 2时候的压缩情况
# k = 4时候的压缩情况
# k = 8时候的压缩情况

# %%
import kmeans
from matplotlib.pyplot import imread
img = imread('sample0.jpg')
fea = img.reshape((img.shape[0]*img.shape[1], 3)).astype(np.float64)
# YOUR (SEVERAL LINES) CODE HERE
# begin answer
print("原图片：")
plt.imshow(fea.reshape(img.shape).astype(np.uint8))
plt.show()
print("进行K聚类以后：")
# 利用Kmeans对图片进行压缩的基本思路是：找到K个中心点
# 用中心点的颜色来代表该类里面所有的颜色，这样就减小了图片的存储空间
for k in [1, 2, 4, 8]:
    print("k = " + str(k) + "时候的压缩情况")
    idx, cters, _ = kmeans.kmeans(fea.copy(), k)
    new_img = cters[idx]
    plt.imshow(new_img.reshape(img.shape).astype(np.uint8))
    plt.show()
# Out:
# 原图片：
# 进行K聚类以后：
# k = 1时候的压缩情况
# k = 2时候的压缩情况
# k = 4时候的压缩情况
# k = 8时候的压缩情况

# %%
import kmeans
from matplotlib.pyplot import imread
img = imread('sample2.jpg')
fea = img.reshape((img.shape[0]*img.shape[1], 3)).astype(np.float64)
# YOUR (SEVERAL LINES) CODE HERE
# begin answer
print("原图片：")
plt.imshow(fea.reshape(img.shape).astype(np.uint8))
plt.show()
print("进行K聚类以后：")
# 利用Kmeans对图片进行压缩的基本思路是：找到K个中心点
# 用中心点的颜色来代表该类里面所有的颜色，这样就减小了图片的存储空间
for k in [1, 2, 4, 8, 16]:
    print("k = " + str(k) + "时候的压缩情况")
    idx, cters, _ = kmeans.kmeans(fea.copy(), k)
    new_img = cters[idx]
    plt.imshow(new_img.reshape(img.shape).astype(np.uint8))
    plt.show()
# Out:
# 原图片：
# 进行K聚类以后：
# k = 1时候的压缩情况
# k = 2时候的压缩情况
# k = 4时候的压缩情况
# k = 8时候的压缩情况
# k = 16时候的压缩情况
