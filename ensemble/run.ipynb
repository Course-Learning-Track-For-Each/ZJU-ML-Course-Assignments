# %% [markdown]
# # A Walk Through Ensemble Models
# *Complete and hand in this completed worksheet (including its outputs and any supporting code outside of the worksheet) with your assignment submission. Please check the pdf file for more details.*
#
# In this exercise you will:
#
# - get to know a useful package **pandas** for data analysis/preprocessing
# - implement **decision tree** and apply it to a Titanic dataset
# - implement a whole bunch of **ensemble methods**, including **random forest, and adaboost**, and apply them to a Titanic dataset
#
# Please note that **YOU CANNOT USE ANY MACHINE LEARNING PACKAGE SUCH AS SKLEARN** for any homework, unless you are asked to.

# %%
# some basic imports
from scipy import io
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import math
import re

# %matplotlib inline

# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# ## Let's first do some data preprocessing
#
# Here we use [pandas](https://pandas.pydata.org/) to do data preprocessing. Pandas is a very popular and handy package for data science or machine learning. You can also refer to this official guide for pandas: [10 minutes to pandas](https://pandas.pydata.org/pandas-docs/stable/getting_started/10min.html)

# %%
# read titanic train and test data
train = pd.read_csv('./input/train.csv')
test = pd.read_csv('./input/test.csv')

print("train shape: {} test shape: {}".format(train.shape, test.shape))
# Showing overview of the train dataset
train.head(3)
# Out:
# train shape: (1047, 11) test shape: (262, 11)
#    Pclass  Survived                              Name     Sex   Age  SibSp  \
# 0       1         1    Hays, Miss. Margaret Bechstein  female  24.0      0
# 1       3         0  Holm, Mr. John Fredrik Alexander    male  43.0      0
# 2       3         0           Hansen, Mr. Claus Peter    male  41.0      2
#
#    Parch  Ticket     Fare Cabin Embarked
# 0      0   11767  83.1583   C54        C
# 1      0  C 7075   6.4500   NaN        S
# 2      0  350026  14.1083   NaN        S

# %% [markdown]
# ## deal with missing values and transform to discrete variables

# %%
# copied from: https://www.kaggle.com/dmilla/introduction-to-decision-trees-titanic-dataset
full_data = [train, test]

# Feature that tells whether a passenger had a cabin on the Titanic
train['Has_Cabin'] = train["Cabin"].apply(lambda x: 0 if type(x) == float else 1)
test['Has_Cabin'] = test["Cabin"].apply(lambda x: 0 if type(x) == float else 1)

# Create new feature FamilySize as a combination of SibSp and Parch
for dataset in full_data:
    dataset['FamilySize'] = dataset['SibSp'] + dataset['Parch'] + 1
# Create new feature IsAlone from FamilySize
for dataset in full_data:
    dataset['IsAlone'] = 0
    dataset.loc[dataset['FamilySize'] == 1, 'IsAlone'] = 1
# Remove all NULLS in the Embarked column
for dataset in full_data:
    dataset['Embarked'] = dataset['Embarked'].fillna('S')
# Remove all NULLS in the Fare column
for dataset in full_data:
    dataset['Fare'] = dataset['Fare'].fillna(train['Fare'].median())

# Remove all NULLS in the Age column
for dataset in full_data:
    age_avg = dataset['Age'].mean()
    age_std = dataset['Age'].std()
    age_null_count = dataset['Age'].isnull().sum()
    age_null_random_list = np.random.randint(age_avg - age_std, age_avg + age_std, size=age_null_count)
    # Next line has been improved to avoid warning
    dataset.loc[np.isnan(dataset['Age']), 'Age'] = age_null_random_list
    dataset['Age'] = dataset['Age'].astype(int)

# Define function to extract titles from passenger names
def get_title(name):
    title_search = re.search(' ([A-Za-z]+)\.', name)
    # If the title exists, extract and return it.
    if title_search:
        return title_search.group(1)
    return ""

for dataset in full_data:
    dataset['Title'] = dataset['Name'].apply(get_title)
# Group all non-common titles into one single grouping "Rare"
for dataset in full_data:
    dataset['Title'] = dataset['Title'].replace(['Lady', 'Countess','Capt', 'Col','Don', 'Dr', 'Major', 'Rev', 'Sir', 'Jonkheer', 'Dona'], 'Rare')

    dataset['Title'] = dataset['Title'].replace('Mlle', 'Miss')
    dataset['Title'] = dataset['Title'].replace('Ms', 'Miss')
    dataset['Title'] = dataset['Title'].replace('Mme', 'Mrs')

for dataset in full_data:
    # Mapping Sex
    dataset['Sex'] = dataset['Sex'].map( {'female': 0, 'male': 1} ).astype(int)
    
    # Mapping titles
    title_mapping = {"Mr": 1, "Master": 2, "Mrs": 3, "Miss": 4, "Rare": 5}
    dataset['Title'] = dataset['Title'].map(title_mapping)
    dataset['Title'] = dataset['Title'].fillna(0)

    # Mapping Embarked
    dataset['Embarked'] = dataset['Embarked'].map( {'S': 0, 'C': 1, 'Q': 2} ).astype(int)
    
    # Mapping Fare
    dataset.loc[ dataset['Fare'] <= 7.91, 'Fare'] = 0
    dataset.loc[(dataset['Fare'] > 7.91) & (dataset['Fare'] <= 14.454), 'Fare'] = 1
    dataset.loc[(dataset['Fare'] > 14.454) & (dataset['Fare'] <= 31), 'Fare'] = 2
    dataset.loc[ dataset['Fare'] > 31, 'Fare'] = 3
    dataset['Fare'] = dataset['Fare'].astype(int)
    
    # Mapping Age
    dataset.loc[ dataset['Age'] <= 16, 'Age'] = 0
    dataset.loc[(dataset['Age'] > 16) & (dataset['Age'] <= 32), 'Age'] = 1
    dataset.loc[(dataset['Age'] > 32) & (dataset['Age'] <= 48), 'Age'] = 2
    dataset.loc[(dataset['Age'] > 48) & (dataset['Age'] <= 64), 'Age'] = 3
    dataset.loc[ dataset['Age'] > 64, 'Age'] = 4

# %%
drop_elements = ['Name', 'Ticket', 'Cabin', 'SibSp']
train = train.drop(drop_elements, axis = 1)
test  = test.drop(drop_elements, axis = 1)

# %%
train.head()
# Out:
#    Pclass  Survived  Sex  Age  Parch  Fare  Embarked  Has_Cabin  FamilySize  \
# 0       1         1    0    1      0     3         1          1           1
# 1       3         0    1    2      0     0         0          0           1
# 2       3         0    1    2      0     1         0          0           3
# 3       3         0    1    1      0     0         2          0           1
# 4       2         0    1    2      0     1         0          0           1
#
#    IsAlone  Title
# 0        1      4
# 1        1      1
# 2        0      1
# 3        1      1
# 4        1      1

# %%
test.head()
# Out:
#    Pclass  Survived  Sex  Age  Parch  Fare  Embarked  Has_Cabin  FamilySize  \
# 0       3         0    1    1      0     0         2          0           1
# 1       3         0    1    1      2     2         0          0           4
# 2       3         0    1    0      2     3         0          0           8
# 3       2         0    1    2      0     1         0          0           1
# 4       3         0    1    1      0     1         0          0           1
#
#    IsAlone  Title
# 0        1      1
# 1        0      2
# 2        0      2
# 3        1      1
# 4        1      1

# %% [markdown]
# One of the good thing of pd.DataFrame is that you can keep the column names along with the data, which can be beneficial for many case.
#
# Another good thing is that pd.DataFrame can be converted to np.array implicitely.
#
# Also, pd provides a lot of useful data manipulating methods for your convenience, though we may not use them in this homework.

# %%
X = train.drop(['Survived'], axis=1)
y = train["Survived"]
X_test = test.drop(['Survived'], axis=1)
y_test = test["Survived"]
print("train: {}, test: {}".format(X.shape, X_test.shape))
# Out:
# train: (1047, 10), test: (262, 10)

# %%
X.head()
# Out:
#    Pclass  Sex  Age  Parch  Fare  Embarked  Has_Cabin  FamilySize  IsAlone  \
# 0       1    0    1      0     3         1          1           1        1
# 1       3    1    2      0     0         0          0           1        1
# 2       3    1    2      0     1         0          0           3        0
# 3       3    1    1      0     0         2          0           1        1
# 4       2    1    2      0     1         0          0           1        1
#
#    Title
# 0      4
# 1      1
# 2      1
# 3      1
# 4      1

# %%
def accuracy(y_gt, y_pred):
    return np.sum(y_gt == y_pred) / y_gt.shape[0]

# %%
print("Survived: {:.4f}, Not Survivied: {:.4f}".format(y.sum() / len(y), 1 - y.sum() / len(y)))
# Out:
# Survived: 0.3878, Not Survivied: 0.6122

# %% [markdown]
# ## Decision Tree
# Now it's your turn to do some real coding. Please implement the decision tree model in **decision_tree.py**. The PDF file provides some hints for this part.

# %%
from decision_tree import DecisionTree
def get_h(dt):
    h = 0
    if type(dt) == dict:
        for t in list(dt.values())[0].values():
            h = max(h, get_h(t))
    return h + 1
criterion = ['entropy', 'infogain_ratio', 'gini']
for i in range(2, 10):
    print("when max_depth = ", i)
    for crit in criterion:
        print("    using ", crit)
        dt = DecisionTree(criterion=crit, max_depth=i, min_samples_leaf=1, sample_feature=False)
        dt.fit(X, y)
        y_train_pred = dt.predict(X)
        y_test_pred = dt.predict(X_test)
        print("        Accuracy on train set: {}".format(accuracy(y, y_train_pred)))
        print("        Accuracy on test set: {}".format(accuracy(y_test, y_test_pred)))

# Plot the decision tree to get an intuition about how it makes decision
# plt.figure(figsize=(20, 10))
# dt.show()
# Out:
# when max_depth =  2
#     using  entropy
#         Accuracy on train set: 0.8013371537726839
#         Accuracy on test set: 0.8129770992366412
#     using  infogain_ratio
#         Accuracy on train set: 0.7822349570200573
#         Accuracy on test set: 0.7709923664122137
#     using  gini
#         Accuracy on train set: 0.8013371537726839
#         Accuracy on test set: 0.8129770992366412
# when max_depth =  3
#     using  entropy
#         Accuracy on train set: 0.8233046800382043
#         Accuracy on test set: 0.8053435114503816
#     using  infogain_ratio
#         Accuracy on train set: 0.8127984718242598
#         Accuracy on test set: 0.7900763358778626
#     using  gini
#         Accuracy on train set: 0.8233046800382043
#         Accuracy on test set: 0.8091603053435115
# when max_depth =  4
#     using  entropy
#         Accuracy on train set: 0.8424068767908309
#         Accuracy on test set: 0.7977099236641222
#     using  infogain_ratio
#         Accuracy on train set: 0.828080229226361
#         Accuracy on test set: 0.7977099236641222
#     using  gini
#         Accuracy on train set: 0.8433619866284623
#         Accuracy on test set: 0.8015267175572519
# when max_depth =  5
#     using  entropy
#         Accuracy on train set: 0.8624641833810889
#         Accuracy on test set: 0.8053435114503816
#     using  infogain_ratio
#         Accuracy on train set: 0.8443170964660937
#         Accuracy on test set: 0.8015267175572519
#     using  gini
#         Accuracy on train set: 0.8624641833810889
#         Accuracy on test set: 0.8091603053435115
# when max_depth =  6
#     using  entropy
#         Accuracy on train set: 0.8729703915950334
#         Accuracy on test set: 0.7977099236641222
#     using  infogain_ratio
#         Accuracy on train set: 0.8548233046800382
#         Accuracy on test set: 0.8091603053435115
#     using  gini
#         Accuracy on train set: 0.8710601719197708
#         Accuracy on test set: 0.8091603053435115
# when max_depth =  7
#     using  entropy
#         Accuracy on train set: 0.8739255014326648
#         Accuracy on test set: 0.7977099236641222
#     using  infogain_ratio
#         Accuracy on train set: 0.8672397325692455
#         Accuracy on test set: 0.7977099236641222
#     using  gini
#         Accuracy on train set: 0.8739255014326648
#         Accuracy on test set: 0.8015267175572519
# when max_depth =  8
#     using  entropy
#         Accuracy on train set: 0.8739255014326648
#         Accuracy on test set: 0.8091603053435115
#     using  infogain_ratio
#         Accuracy on train set: 0.8729703915950334
#         Accuracy on test set: 0.7977099236641222
#     using  gini
#         Accuracy on train set: 0.8739255014326648
#         Accuracy on test set: 0.8015267175572519
# when max_depth =  9
#     using  entropy
#         Accuracy on train set: 0.8739255014326648
#         Accuracy on test set: 0.8091603053435115
#     using  infogain_ratio
#         Accuracy on train set: 0.8739255014326648
#         Accuracy on test set: 0.8015267175572519
#     using  gini
#         Accuracy on train set: 0.8739255014326648
#         Accuracy on test set: 0.8053435114503816

# %%
# TODO: Train the best DecisionTree(best val accuracy) that you can. You should choose some 
# hyper-parameters such as critertion, max_depth, and min_samples_in_leaf 
# according to the cross-validation result.
# To reduce difficulty, you can use KFold here.
from sklearn.model_selection import KFold
kf = KFold(n_splits=5, shuffle=True, random_state=2020)

best_method = ""
best_acc, best_min_leaf, best_depth = 0, 0, 0
criterion = ['entropy', 'gini', 'infogain_ratio']
for i in range(2, 11): # min_sample_leaf
    print("When min_sample_leaf = ", i)
    for j in range(4, 11): # max_depth
        print("    when max_depth = ", j)
        for crit in criterion:
            print("        use ", crit, end=':')
            dt = DecisionTree(criterion=crit, max_depth=j, min_samples_leaf=i, sample_feature=False)
            avg_accurancy = 0
            for train_indice, valid_indice in kf.split(X, y):
                X_train_fold, y_train_fold = X.loc[train_indice], y.loc[train_indice]
                X_val_fold, y_val_fold = X.loc[valid_indice], y.loc[valid_indice]
                dt.fit(X_train_fold, y_train_fold)
                y_train_pred = dt.predict(X_train_fold)
                y_valid_pred = dt.predict(X_val_fold)
                avg_accurancy += accuracy(y_train_fold, y_train_pred) * 0.25 + accuracy(y_val_fold, y_valid_pred) * 0.75
            avg_accurancy /= 5
            print("accuracy = ", avg_accurancy)
            if avg_accurancy > best_acc:
                best_acc = avg_accurancy
                best_min_leaf = i
                best_depth = j
                best_method = crit

# begin answer
print("The best decision tree is:")
print("best accurancy = ", best_acc)
print("best min leaf = ", best_min_leaf)
print("best depth = ", best_depth)
print("best criterion = ", best_method)
# end answer
# Out:
# When min_sample_leaf =  2
#     when max_depth =  4
#         use  entropy:accuracy =  0.7948289503518827
#         use  gini:accuracy =  0.7863376260839499
#         use  infogain_ratio:accuracy =  0.7985905134292232
#     when max_depth =  5
#         use  entropy:accuracy =  0.7959612352312044
#         use  gini:accuracy =  0.7881295818952175
#         use  infogain_ratio:accuracy =  0.7975157863322545
#     when max_depth =  6
#         use  entropy:accuracy =  0.7913089673498278
#         use  gini:accuracy =  0.786404233076316
#         use  infogain_ratio:accuracy =  0.7941568044182806
#     when max_depth =  7
#         use  entropy:accuracy =  0.7932783056804394
#         use  gini:accuracy =  0.7888030557348118
#         use  infogain_ratio:accuracy =  0.7942867271326979
#     when max_depth =  8
#         use  entropy:accuracy =  0.7890982525969823
#         use  gini:accuracy =  0.7840741865812269
#         use  infogain_ratio:accuracy =  0.7902776224945186
#     when max_depth =  9
#         use  entropy:accuracy =  0.7905302416605504
#         use  gini:accuracy =  0.7869449999783561
#         use  infogain_ratio:accuracy =  0.7913570238470863
#     when max_depth =  10
#         use  entropy:accuracy =  0.792088397736355
#         use  gini:accuracy =  0.7870644742913788
#         use  infogain_ratio:accuracy =  0.7913536062120897
# When min_sample_leaf =  3
#     when max_depth =  4
#         use  entropy:accuracy =  0.7959028016179411
#         use  gini:accuracy =  0.7846037474589975
#         use  infogain_ratio:accuracy =  0.8006907928759415
#     when max_depth =  5
#         use  entropy:accuracy =  0.7914141479141217
#         use  gini:accuracy =  0.7856793563898565
#         use  infogain_ratio:accuracy =  0.8000914741526028
#     when max_depth =  6
#         use  entropy:accuracy =  0.7902952198703461
#         use  gini:accuracy =  0.7822843550648252
#         use  infogain_ratio:accuracy =  0.7942280796632657
#     when max_depth =  7
#         use  entropy:accuracy =  0.7911818104987832
#         use  gini:accuracy =  0.7866929612985588
#         use  infogain_ratio:accuracy =  0.7870729613749214
#     when max_depth =  8
#         use  entropy:accuracy =  0.7919625973541837
#         use  gini:accuracy =  0.7825829695619922
#         use  infogain_ratio:accuracy =  0.78766655887809
#     when max_depth =  9
#         use  entropy:accuracy =  0.7883809158777655
#         use  gini:accuracy =  0.7833006729112746
#         use  infogain_ratio:accuracy =  0.7885599847765203
#     when max_depth =  10
#         use  entropy:accuracy =  0.7920188455903089
#         use  gini:accuracy =  0.7847292443398459
#         use  infogain_ratio:accuracy =  0.7864137099986666
# When min_sample_leaf =  4
#     when max_depth =  4
#         use  entropy:accuracy =  0.8006214178665362
#         use  gini:accuracy =  0.7906315321085309
#         use  infogain_ratio:accuracy =  0.8006907928759415
#     when max_depth =  5
#         use  entropy:accuracy =  0.7958905404724539
#         use  gini:accuracy =  0.7915383250456247
#         use  infogain_ratio:accuracy =  0.8015200455811742
#     when max_depth =  6
#         use  entropy:accuracy =  0.7951209963608512
#         use  gini:accuracy =  0.7884262065116513
#         use  infogain_ratio:accuracy =  0.7954775821930824
#     when max_depth =  7
#         use  entropy:accuracy =  0.7917218727035739
#         use  gini:accuracy =  0.7907022085075175
#         use  infogain_ratio:accuracy =  0.7927989990338495
#     when max_depth =  8
#         use  entropy:accuracy =  0.7939278133525494
#         use  gini:accuracy =  0.7887316562788115
#         use  infogain_ratio:accuracy =  0.7926118096816178
#     when max_depth =  9
#         use  entropy:accuracy =  0.7953563847811207
#         use  gini:accuracy =  0.7901636453423796
#         use  infogain_ratio:accuracy =  0.7899235541036296
#     when max_depth =  10
#         use  entropy:accuracy =  0.793987479223671
#         use  gini:accuracy =  0.7901670629773762
#         use  infogain_ratio:accuracy =  0.7913589608021943
# When min_sample_leaf =  5
#     when max_depth =  4
#         use  entropy:accuracy =  0.8013934508565999
#         use  gini:accuracy =  0.7905767829120586
#         use  infogain_ratio:accuracy =  0.8005645545783151
#     when max_depth =  5
#         use  entropy:accuracy =  0.793929393880709
#         use  gini:accuracy =  0.7899163807664523
#         use  infogain_ratio:accuracy =  0.8019990141605801
#     when max_depth =  6
#         use  entropy:accuracy =  0.7965026539048689
#         use  gini:accuracy =  0.7895096059854498
#         use  infogain_ratio:accuracy =  0.7970270556889397
#     when max_depth =  7
#         use  entropy:accuracy =  0.7959010072336126
#         use  gini:accuracy =  0.791057651727044
#         use  infogain_ratio:accuracy =  0.7956576409306452
#     when max_depth =  8
#         use  entropy:accuracy =  0.792378991628316
#         use  gini:accuracy =  0.7890939347683313
#         use  infogain_ratio:accuracy =  0.7967864552493449
#     when max_depth =  9
#         use  entropy:accuracy =  0.7959606731047343
#         use  gini:accuracy =  0.7890870994983381
#         use  infogain_ratio:accuracy =  0.7969690130684859
#     when max_depth =  10
#         use  entropy:accuracy =  0.796020338975856
#         use  gini:accuracy =  0.7898048028476203
#         use  infogain_ratio:accuracy =  0.7933907492270642
# When min_sample_leaf =  6
#     when max_depth =  4
#         use  entropy:accuracy =  0.796144391896344
#         use  gini:accuracy =  0.7889656536643461
#         use  infogain_ratio:accuracy =  0.8011663438203506
#     when max_depth =  5
#         use  entropy:accuracy =  0.795538533247688
#         use  gini:accuracy =  0.7879506026416165
#         use  infogain_ratio:accuracy =  0.8016476403476739
#     when max_depth =  6
#         use  entropy:accuracy =  0.7959689361289906
#         use  gini:accuracy =  0.7882546959399033
#         use  infogain_ratio:accuracy =  0.7977494618567025
#     when max_depth =  7
#         use  entropy:accuracy =  0.7925033113305984
#         use  gini:accuracy =  0.7876598845386402
#         use  infogain_ratio:accuracy =  0.7934529141797639
#     when max_depth =  8
#         use  entropy:accuracy =  0.7932806805510024
#         use  gini:accuracy =  0.7914241238341996
#         use  infogain_ratio:accuracy =  0.7937515286769312
#     when max_depth =  9
#         use  entropy:accuracy =  0.7939915486302915
#         use  gini:accuracy =  0.7892710137863527
#         use  infogain_ratio:accuracy =  0.7924458491963791
#     when max_depth =  10
#         use  entropy:accuracy =  0.7962077421842567
#         use  gini:accuracy =  0.7864002003892234
#         use  infogain_ratio:accuracy =  0.7924390139263858
# When min_sample_leaf =  7
#     when max_depth =  4
#         use  entropy:accuracy =  0.7988821317258538
#         use  gini:accuracy =  0.7895639539859953
#         use  infogain_ratio:accuracy =  0.8024823474912821
#     when max_depth =  5
#         use  entropy:accuracy =  0.7946416897142612
#         use  gini:accuracy =  0.7892069404414264
#         use  infogain_ratio:accuracy =  0.7985414385302753
#     when max_depth =  6
#         use  entropy:accuracy =  0.7950090090894457
#         use  gini:accuracy =  0.7858696863921731
#         use  infogain_ratio:accuracy =  0.7966702030749141
#     when max_depth =  7
#         use  entropy:accuracy =  0.7950687462459569
#         use  gini:accuracy =  0.788132017848053
#         use  infogain_ratio:accuracy =  0.7915400379414465
#     when max_depth =  8
#         use  entropy:accuracy =  0.7943510428966747
#         use  gini:accuracy =  0.7896868275742507
#         use  infogain_ratio:accuracy =  0.7903401622339307
#     when max_depth =  9
#         use  entropy:accuracy =  0.795779614325246
#         use  gini:accuracy =  0.7882514208756859
#         use  infogain_ratio:accuracy =  0.7896890313111529
#     when max_depth =  10
#         use  entropy:accuracy =  0.7972712692599359
#         use  gini:accuracy =  0.7911188166378186
#         use  infogain_ratio:accuracy =  0.79183188845401
# When min_sample_leaf =  8
#     when max_depth =  4
#         use  entropy:accuracy =  0.7966198715553634
#         use  gini:accuracy =  0.7901622543076444
#         use  infogain_ratio:accuracy =  0.8033702233032031
#     when max_depth =  5
#         use  entropy:accuracy =  0.7944097902143779
#         use  gini:accuracy =  0.7882505023222676
#         use  infogain_ratio:accuracy =  0.8021175699201842
#     when max_depth =  6
#         use  entropy:accuracy =  0.7960760250855109
#         use  gini:accuracy =  0.7890898124360852
#         use  infogain_ratio:accuracy =  0.7973192728315686
#     when max_depth =  7
#         use  entropy:accuracy =  0.7961391798770188
#         use  gini:accuracy =  0.7892058691141114
#         use  infogain_ratio:accuracy =  0.7913520013211858
#     when max_depth =  8
#         use  entropy:accuracy =  0.7982888722898691
#         use  gini:accuracy =  0.7907572612053123
#         use  infogain_ratio:accuracy =  0.7915909499472312
#     when max_depth =  9
#         use  entropy:accuracy =  0.7961391798770188
#         use  gini:accuracy =  0.7886109864274587
#         use  infogain_ratio:accuracy =  0.7923581375480351
#     when max_depth =  10
#         use  entropy:accuracy =  0.7962022633831372
#         use  gini:accuracy =  0.7907572612053123
#         use  infogain_ratio:accuracy =  0.7923649728180282
# When min_sample_leaf =  9
#     when max_depth =  4
#         use  entropy:accuracy =  0.7993012205779688
#         use  gini:accuracy =  0.7900325270896321
#         use  infogain_ratio:accuracy =  0.8039685236248524
#     when max_depth =  5
#         use  entropy:accuracy =  0.7977423414451507
#         use  gini:accuracy =  0.7895561818028197
#         use  infogain_ratio:accuracy =  0.8012207976721472
#     when max_depth =  6
#         use  entropy:accuracy =  0.8005556927080605
#         use  gini:accuracy =  0.7850236835791414
#         use  infogain_ratio:accuracy =  0.7977982414109744
#     when max_depth =  7
#         use  entropy:accuracy =  0.797030330753157
#         use  gini:accuracy =  0.7880105536542967
#         use  infogain_ratio:accuracy =  0.7921273806608563
#     when max_depth =  8
#         use  entropy:accuracy =  0.7991800231660073
#         use  gini:accuracy =  0.7888442423962155
#         use  infogain_ratio:accuracy =  0.7901603173525367
#     when max_depth =  9
#         use  entropy:accuracy =  0.798462319816725
#         use  gini:accuracy =  0.7895585281105013
#         use  infogain_ratio:accuracy =  0.7916486259376195
#     when max_depth =  10
#         use  entropy:accuracy =  0.7992431066721256
#         use  gini:accuracy =  0.7902762314597835
#         use  infogain_ratio:accuracy =  0.7923594940169086
# When min_sample_leaf =  10
#     when max_depth =  4
#         use  entropy:accuracy =  0.8001364083595405
#         use  gini:accuracy =  0.7943965657464936
#         use  infogain_ratio:accuracy =  0.8039685236248524
#     when max_depth =  5
#         use  entropy:accuracy =  0.7998900439772675
#         use  gini:accuracy =  0.7917107908903193
#         use  infogain_ratio:accuracy =  0.8004467748013502
#     when max_depth =  6
#         use  entropy:accuracy =  0.8019260260197735
#         use  gini:accuracy =  0.7906405711154264
#         use  infogain_ratio:accuracy =  0.7969014691629374
#     when max_depth =  7
#         use  entropy:accuracy =  0.8012646421920058
#         use  gini:accuracy =  0.7900423420791668
#         use  infogain_ratio:accuracy =  0.7946928868616046
#     when max_depth =  8
#         use  entropy:accuracy =  0.798407499334863
#         use  gini:accuracy =  0.7930291408689325
#         use  infogain_ratio:accuracy =  0.7941612302518495
#     when max_depth =  9
#         use  entropy:accuracy =  0.8005606093827099
#         use  gini:accuracy =  0.7951719980117895
#         use  infogain_ratio:accuracy =  0.7942209674083609
#     when max_depth =  10
#         use  entropy:accuracy =  0.8020420114124098
#         use  gini:accuracy =  0.7923080198846536
#         use  infogain_ratio:accuracy =  0.7949352531226465
# The best decision tree is:
# best accurancy =  0.8039685236248524
# best min leaf =  9
# best depth =  4
# best criterion =  infogain_ratio

# %%
# report the accuracy on test set
# begin answer
dt = DecisionTree(criterion="entropy", max_depth=best_depth, min_samples_leaf=best_min_leaf, sample_feature=False)
# end answer
dt.fit(X, y)
print("Accuracy on train set: {}".format(accuracy(y, dt.predict(X))))
print("Accuracy on test set: {}".format(accuracy(y_test, dt.predict(X_test))))
# Out:
# Accuracy on train set: 0.8347659980897804
# Accuracy on test set: 0.7900763358778626

# %% [markdown]
# ## Random Forest
# Please implement the random forest model in **random_forest.py**. The PDF file provides some hints for this part.

# %%
from random_forest import RandomForest

base_learner = DecisionTree(criterion='entropy', max_depth=2, min_samples_leaf=1, sample_feature=True)
rf = RandomForest(base_learner=base_learner, n_estimator=10, seed=2020)
rf.fit(X, y)

y_train_pred = rf.predict(X)

print("Accuracy on train set: {}".format(accuracy(y, y_train_pred)))
# Out:
# Accuracy on train set: 0.7984718242597899

# %%
# TODO: Train the best RandomForest that you can. You should choose some 
# hyper-parameters such as max_depth, and min_samples_in_leaf 
# according to the cross-validation result.
# begin answer
from sklearn.model_selection import KFold
kf = KFold(n_splits=5, shuffle=True, random_state=2020)

best_method = ""
best_acc, best_min_leaf, best_depth = 0, 0, 0
criterion = ['entropy', 'gini', 'infogain_ratio']
for i in range(2, 11): # min_sample_leaf
    print("When min_sample_leaf = ", i)
    for j in range(4, 11): # max_depth
        print("    when max_depth = ", j)
        for crit in criterion:
            print("        use ", crit, end=':')
            base_leaner = DecisionTree(criterion=crit, max_depth=j, min_samples_leaf=i, sample_feature=False)
            rf = RandomForest(base_learner=base_learner, n_estimator=10, seed=2020)
            avg_accurancy = 0
            for train_indice, valid_indice in kf.split(X, y):
                X_train_fold, y_train_fold = X.loc[train_indice], y.loc[train_indice]
                X_val_fold, y_val_fold = X.loc[valid_indice], y.loc[valid_indice]
                rf.fit(X_train_fold, y_train_fold)
                y_train_pred = rf.predict(X_train_fold)
                y_valid_pred = rf.predict(X_val_fold)
                avg_accurancy += accuracy(y_train_fold, y_train_pred) * 0.25 + accuracy(y_val_fold, y_valid_pred) * 0.75
            avg_accurancy /= 5
            print("accuracy = ", avg_accurancy)
            if avg_accurancy > best_acc:
                best_acc = avg_accurancy
                best_min_leaf = i
                best_depth = j
                best_method = crit

# begin answer
print("The best decision tree is:")
print("best accurancy = ", best_acc)
print("best min leaf = ", best_min_leaf)
print("best depth = ", best_depth)
print("best criterion = ", best_method)
# end answer
# Out:
# When min_sample_leaf =  2
#     when max_depth =  4
#         use  entropy:accuracy =  0.7961611868803177
#         use  gini:accuracy =  0.7961611868803177
#         use  infogain_ratio:accuracy =  0.7968788902296
#     when max_depth =  5
#         use  entropy:accuracy =  0.7954469011660319
#         use  gini:accuracy =  0.7961611868803177
#         use  infogain_ratio:accuracy =  0.7961611868803177
#     when max_depth =  6
#         use  entropy:accuracy =  0.7961611868803177
#         use  gini:accuracy =  0.7954469011660319
#         use  infogain_ratio:accuracy =  0.7954469011660319
#     when max_depth =  7
#         use  entropy:accuracy =  0.7961611868803177
#         use  gini:accuracy =  0.7954469011660319
#         use  infogain_ratio:accuracy =  0.7961611868803177
#     when max_depth =  8
#         use  entropy:accuracy =  0.7954469011660319
#         use  gini:accuracy =  0.7961611868803177
#         use  infogain_ratio:accuracy =  0.7961611868803177
#     when max_depth =  9
#         use  entropy:accuracy =  0.7968788902296
#         use  gini:accuracy =  0.7961611868803177
#         use  infogain_ratio:accuracy =  0.7954469011660319
#     when max_depth =  10
#         use  entropy:accuracy =  0.7954469011660319
#         use  gini:accuracy =  0.7954469011660319
#         use  infogain_ratio:accuracy =  0.7954469011660319
# When min_sample_leaf =  3
#     when max_depth =  4
#         use  entropy:accuracy =  0.7961646045153142
#         use  gini:accuracy =  0.7961611868803177
#         use  infogain_ratio:accuracy =  0.7954469011660319
#     when max_depth =  5
#         use  entropy:accuracy =  0.7961611868803177
#         use  gini:accuracy =  0.7961611868803177
#         use  infogain_ratio:accuracy =  0.7961611868803177
#     when max_depth =  6
#         use  entropy:accuracy =  0.7961611868803177
#         use  gini:accuracy =  0.7961611868803177
#         use  infogain_ratio:accuracy =  0.7961611868803177
#     when max_depth =  7
#         use  entropy:accuracy =  0.7954469011660319
#         use  gini:accuracy =  0.7961611868803177
#         use  infogain_ratio:accuracy =  0.7961611868803177
#     when max_depth =  8
#         use  entropy:accuracy =  0.7954469011660319
#         use  gini:accuracy =  0.7961611868803177
#         use  infogain_ratio:accuracy =  0.7961611868803177
#     when max_depth =  9
#         use  entropy:accuracy =  0.7954469011660319
#         use  gini:accuracy =  0.7961611868803177
#         use  infogain_ratio:accuracy =  0.7961611868803177
#     when max_depth =  10
#         use  entropy:accuracy =  0.7961611868803177
#         use  gini:accuracy =  0.7961611868803177
#         use  infogain_ratio:accuracy =  0.7954469011660319
# When min_sample_leaf =  4
#     when max_depth =  4
#         use  entropy:accuracy =  0.7961611868803177
#         use  gini:accuracy =  0.7961611868803177
#         use  infogain_ratio:accuracy =  0.7961611868803177
#     when max_depth =  5
#         use  entropy:accuracy =  0.7961611868803177
#         use  gini:accuracy =  0.7968788902296
#         use  infogain_ratio:accuracy =  0.7961611868803177
#     when max_depth =  6
#         use  entropy:accuracy =  0.7954469011660319
#         use  gini:accuracy =  0.7961611868803177
#         use  infogain_ratio:accuracy =  0.7954469011660319
#     when max_depth =  7
#         use  entropy:accuracy =  0.7961611868803177
#         use  gini:accuracy =  0.7968788902296
#         use  infogain_ratio:accuracy =  0.7961646045153142
#     when max_depth =  8
#         use  entropy:accuracy =  0.7954469011660319
#         use  gini:accuracy =  0.7961611868803177
#         use  infogain_ratio:accuracy =  0.7968788902296
#     when max_depth =  9
#         use  entropy:accuracy =  0.7961611868803177
#         use  gini:accuracy =  0.7961611868803177
#         use  infogain_ratio:accuracy =  0.7968788902296
#     when max_depth =  10
#         use  entropy:accuracy =  0.7954469011660319
#         use  gini:accuracy =  0.7961646045153142
#         use  infogain_ratio:accuracy =  0.7961611868803177
# When min_sample_leaf =  5
#     when max_depth =  4
#         use  entropy:accuracy =  0.7961611868803177
#         use  gini:accuracy =  0.7954469011660319
#         use  infogain_ratio:accuracy =  0.7961611868803177
#     when max_depth =  5
#         use  entropy:accuracy =  0.7954469011660319
#         use  gini:accuracy =  0.7954469011660319
#         use  infogain_ratio:accuracy =  0.7954469011660319
#     when max_depth =  6
#         use  entropy:accuracy =  0.7961611868803177
#         use  gini:accuracy =  0.7961611868803177
#         use  infogain_ratio:accuracy =  0.7961611868803177
#     when max_depth =  7
#         use  entropy:accuracy =  0.7961611868803177
#         use  gini:accuracy =  0.7954469011660319
#         use  infogain_ratio:accuracy =  0.7954469011660319
#     when max_depth =  8
#         use  entropy:accuracy =  0.7968788902296
#         use  gini:accuracy =  0.7961611868803177
#         use  infogain_ratio:accuracy =  0.7961611868803177
#     when max_depth =  9
#         use  entropy:accuracy =  0.7961611868803177
#         use  gini:accuracy =  0.7954469011660319
#         use  infogain_ratio:accuracy =  0.7954469011660319
#     when max_depth =  10
#         use  entropy:accuracy =  0.7961611868803177
#         use  gini:accuracy =  0.7961611868803177
#         use  infogain_ratio:accuracy =  0.7961611868803177
# When min_sample_leaf =  6
#     when max_depth =  4
#         use  entropy:accuracy =  0.7954469011660319
#         use  gini:accuracy =  0.7961611868803177
#         use  infogain_ratio:accuracy =  0.7961611868803177
#     when max_depth =  5
#         use  entropy:accuracy =  0.7961611868803177
#         use  gini:accuracy =  0.7961611868803177
#         use  infogain_ratio:accuracy =  0.7954469011660319
#     when max_depth =  6
#         use  entropy:accuracy =  0.7954469011660319
#         use  gini:accuracy =  0.7968788902296
#         use  infogain_ratio:accuracy =  0.7954469011660319
#     when max_depth =  7
#         use  entropy:accuracy =  0.7961611868803177
#         use  gini:accuracy =  0.7961611868803177
#         use  infogain_ratio:accuracy =  0.7961611868803177
#     when max_depth =  8
#         use  entropy:accuracy =  0.7954469011660319
#         use  gini:accuracy =  0.7961611868803177
#         use  infogain_ratio:accuracy =  0.7954469011660319
#     when max_depth =  9
#         use  entropy:accuracy =  0.7954469011660319
#         use  gini:accuracy =  0.7954469011660319
#         use  infogain_ratio:accuracy =  0.7954469011660319
#     when max_depth =  10
#         use  entropy:accuracy =  0.7961611868803177
#         use  gini:accuracy =  0.7954469011660319
#         use  infogain_ratio:accuracy =  0.7968788902296
# When min_sample_leaf =  7
#     when max_depth =  4
#         use  entropy:accuracy =  0.7961611868803177
#         use  gini:accuracy =  0.7954469011660319
#         use  infogain_ratio:accuracy =  0.7954469011660319
#     when max_depth =  5
#         use  entropy:accuracy =  0.7961611868803177
#         use  gini:accuracy =  0.7961611868803177
#         use  infogain_ratio:accuracy =  0.7961611868803177
#     when max_depth =  6
#         use  entropy:accuracy =  0.7961611868803177
#         use  gini:accuracy =  0.7961611868803177
#         use  infogain_ratio:accuracy =  0.7961611868803177
#     when max_depth =  7
#         use  entropy:accuracy =  0.7961611868803177
#         use  gini:accuracy =  0.7961611868803177
#         use  infogain_ratio:accuracy =  0.7961611868803177
#     when max_depth =  8
#         use  entropy:accuracy =  0.7961611868803177
#         use  gini:accuracy =  0.7954469011660319
#         use  infogain_ratio:accuracy =  0.7961611868803177
#     when max_depth =  9
#         use  entropy:accuracy =  0.7961611868803177
#         use  gini:accuracy =  0.7961611868803177
#         use  infogain_ratio:accuracy =  0.7954469011660319
#     when max_depth =  10
#         use  entropy:accuracy =  0.7954469011660319
#         use  gini:accuracy =  0.7954469011660319
#         use  infogain_ratio:accuracy =  0.7961611868803177
# When min_sample_leaf =  8
#     when max_depth =  4
#         use  entropy:accuracy =  0.7961611868803177
#         use  gini:accuracy =  0.7954469011660319
#         use  infogain_ratio:accuracy =  0.7961611868803177
#     when max_depth =  5
#         use  entropy:accuracy =  0.7961611868803177
#         use  gini:accuracy =  0.7961611868803177
#         use  infogain_ratio:accuracy =  0.7961611868803177
#     when max_depth =  6
#         use  entropy:accuracy =  0.7961646045153142
#         use  gini:accuracy =  0.7961646045153142
#         use  infogain_ratio:accuracy =  0.7954469011660319
#     when max_depth =  7
#         use  entropy:accuracy =  0.7961611868803177
#         use  gini:accuracy =  0.7961611868803177
#         use  infogain_ratio:accuracy =  0.7961611868803177
#     when max_depth =  8
#         use  entropy:accuracy =  0.7961611868803177
#         use  gini:accuracy =  0.7961611868803177
#         use  infogain_ratio:accuracy =  0.7961611868803177
#     when max_depth =  9
#         use  entropy:accuracy =  0.7968788902296
#         use  gini:accuracy =  0.7961611868803177
#         use  infogain_ratio:accuracy =  0.7961611868803177
#     when max_depth =  10
#         use  entropy:accuracy =  0.7961611868803177
#         use  gini:accuracy =  0.7954469011660319
#         use  infogain_ratio:accuracy =  0.7961611868803177
# When min_sample_leaf =  9
#     when max_depth =  4
#         use  entropy:accuracy =  0.7968788902296
#         use  gini:accuracy =  0.7954469011660319
#         use  infogain_ratio:accuracy =  0.7954469011660319
#     when max_depth =  5
#         use  entropy:accuracy =  0.7968788902296
#         use  gini:accuracy =  0.7961611868803177
#         use  infogain_ratio:accuracy =  0.7954469011660319
#     when max_depth =  6
#         use  entropy:accuracy =  0.7961611868803177
#         use  gini:accuracy =  0.7961611868803177
#         use  infogain_ratio:accuracy =  0.7961611868803177
#     when max_depth =  7
#         use  entropy:accuracy =  0.7954469011660319
#         use  gini:accuracy =  0.7961611868803177
#         use  infogain_ratio:accuracy =  0.7961611868803177
#     when max_depth =  8
#         use  entropy:accuracy =  0.7961611868803177
#         use  gini:accuracy =  0.7968788902296
#         use  infogain_ratio:accuracy =  0.7961646045153142
#     when max_depth =  9
#         use  entropy:accuracy =  0.7961611868803177
#         use  gini:accuracy =  0.7954469011660319
#         use  infogain_ratio:accuracy =  0.7954469011660319
#     when max_depth =  10
#         use  entropy:accuracy =  0.7961611868803177
#         use  gini:accuracy =  0.7961611868803177
#         use  infogain_ratio:accuracy =  0.7954469011660319
# When min_sample_leaf =  10
#     when max_depth =  4
#         use  entropy:accuracy =  0.7961611868803177
#         use  gini:accuracy =  0.7961611868803177
#         use  infogain_ratio:accuracy =  0.7961611868803177
#     when max_depth =  5
#         use  entropy:accuracy =  0.7961611868803177
#         use  gini:accuracy =  0.7954469011660319
#         use  infogain_ratio:accuracy =  0.7954469011660319
#     when max_depth =  6
#         use  entropy:accuracy =  0.7961646045153142
#         use  gini:accuracy =  0.7961611868803177
#         use  infogain_ratio:accuracy =  0.7961611868803177
#     when max_depth =  7
#         use  entropy:accuracy =  0.7961611868803177
#         use  gini:accuracy =  0.7954469011660319
#         use  infogain_ratio:accuracy =  0.7961611868803177
#     when max_depth =  8
#         use  entropy:accuracy =  0.7954469011660319
#         use  gini:accuracy =  0.7968788902296
#         use  infogain_ratio:accuracy =  0.7961611868803177
#     when max_depth =  9
#         use  entropy:accuracy =  0.7954469011660319
#         use  gini:accuracy =  0.7961611868803177
#         use  infogain_ratio:accuracy =  0.7954469011660319
#     when max_depth =  10
#         use  entropy:accuracy =  0.7961611868803177
#         use  gini:accuracy =  0.7961611868803177
#         use  infogain_ratio:accuracy =  0.7954469011660319
# The best decision tree is:
# best accurancy =  0.7968788902296
# best min leaf =  2
# best depth =  4
# best criterion =  infogain_ratio

# %%
# report the accuracy on test set
# begin answer
dt = DecisionTree(criterion=best_method, max_depth=best_depth, min_samples_leaf=best_min_leaf, sample_feature=False)
rf = RandomForest(base_learner=base_learner, n_estimator=10, seed=2020)
# end answer
rf.fit(X, y)
print("Accuracy on train set: {}".format(accuracy(y, rf.predict(X))))
print("Accuracy on test set: {}".format(accuracy(y_test, rf.predict(X_test))))
# Out:
# Accuracy on train set: 0.7984718242597899
# Accuracy on test set: 0.7862595419847328

# %% [markdown]
# ## Adaboost
# Please implement the adaboost model in **adaboost.py**. The PDF file provides some hints for this part.

# %%
from adaboost import Adaboost

base_learner = DecisionTree(criterion='entropy', max_depth=1, min_samples_leaf=1, sample_feature=False)
ada = Adaboost(base_learner=base_learner, n_estimator=50, seed=2020)
ada.fit(X, y)

y_train_pred = ada.predict(X)

print("Accuracy on train set: {}".format(accuracy(y, y_train_pred)))
# Out:
# Accuracy on train set: 0.8099331423113658

# %%
# TODO: Train the best Adaboost that you can. You should choose some 
# hyper-parameters such as max_depth, and min_samples_in_leaf 
# according to the cross-validation result.
# begin answer
from sklearn.model_selection import KFold
kf = KFold(n_splits=5, shuffle=True, random_state=2020)

best_method = ""
best_acc, best_min_leaf, best_depth = 0, 0, 0
criterion = ['entropy', 'gini', 'infogain_ratio']
for i in range(2, 11): # min_sample_leaf
    print("When min_sample_leaf = ", i)
    for j in range(4, 11): # max_depth
        print("    when max_depth = ", j)
        for crit in criterion:
            print("        use ", crit)
            base_leaner = DecisionTree(criterion=crit, max_depth=j, min_samples_leaf=i, sample_feature=False)
            ada = Adaboost(base_learner=base_learner, n_estimator=50, seed=2020)
            avg_accurancy, avg_train, avg_test = 0, 0, 0
            for train_indice, valid_indice in kf.split(X, y):
                X_train_fold, y_train_fold = X.loc[train_indice], y.loc[train_indice]
                X_val_fold, y_val_fold = X.loc[valid_indice], y.loc[valid_indice]
                ada.fit(X_train_fold, y_train_fold)
                y_train_pred = ada.predict(X_train_fold)
                y_valid_pred = ada.predict(X_val_fold)
                train_acc, test_acc = accuracy(y_train_fold, y_train_pred), accuracy(y_val_fold, y_valid_pred)
                avg_train += train_acc
                avg_test += test_acc
                avg_accurancy += train_acc * 0.2 + test_acc * 0.8
            avg_accurancy /= 5
            avg_train /= 5
            avg_test /= 5
            print("            train accurancy = ", avg_train)
            print("            test accurancy = ", avg_test)
            print("            total accurancy = ", avg_accurancy)
            if avg_accurancy > best_acc:
                best_acc = avg_accurancy
                best_min_leaf = i
                best_depth = j
                best_method = crit

# begin answer
print("The best decision tree using adaboost is:")
print("best accurancy = ", best_acc)
print("best min leaf = ", best_min_leaf)
print("best depth = ", best_depth)
print("best criterion = ", best_method)
# end answer
# Out:
# When min_sample_leaf =  2
#     when max_depth =  4
#         use  entropy
#             train accurancy =  0.8096950981314673
#             test accurancy =  0.8042059694691274
#             total accurancy =  0.8053037952015953
#         use  gini
#             train accurancy =  0.8096950981314673
#             test accurancy =  0.8042059694691274
#             total accurancy =  0.8053037952015953
#         use  infogain_ratio
#             train accurancy =  0.8096950981314673
#             test accurancy =  0.8042059694691274
#             total accurancy =  0.8053037952015953
#     when max_depth =  5
#         use  entropy
#             train accurancy =  0.8096950981314673
#             test accurancy =  0.8042059694691274
#             total accurancy =  0.8053037952015953
#         use  gini
#             train accurancy =  0.8096950981314673
#             test accurancy =  0.8042059694691274
#             total accurancy =  0.8053037952015953
#         use  infogain_ratio
#             train accurancy =  0.8096950981314673
#             test accurancy =  0.8042059694691274
#             total accurancy =  0.8053037952015953
#     when max_depth =  6
#         use  entropy
#             train accurancy =  0.8096950981314673
#             test accurancy =  0.8042059694691274
#             total accurancy =  0.8053037952015953
#         use  gini
#             train accurancy =  0.8096950981314673
#             test accurancy =  0.8042059694691274
#             total accurancy =  0.8053037952015953
#         use  infogain_ratio
#             train accurancy =  0.8096950981314673
#             test accurancy =  0.8042059694691274
#             total accurancy =  0.8053037952015953
#     when max_depth =  7
#         use  entropy
#             train accurancy =  0.8096950981314673
#             test accurancy =  0.8042059694691274
#             total accurancy =  0.8053037952015953
#         use  gini
#             train accurancy =  0.8096950981314673
#             test accurancy =  0.8042059694691274
#             total accurancy =  0.8053037952015953
#         use  infogain_ratio
#             train accurancy =  0.8096950981314673
#             test accurancy =  0.8042059694691274
#             total accurancy =  0.8053037952015953
#     when max_depth =  8
#         use  entropy
#             train accurancy =  0.8096950981314673
#             test accurancy =  0.8042059694691274
#             total accurancy =  0.8053037952015953
#         use  gini
#             train accurancy =  0.8096950981314673
#             test accurancy =  0.8042059694691274
#             total accurancy =  0.8053037952015953
#         use  infogain_ratio
#             train accurancy =  0.8096950981314673
#             test accurancy =  0.8042059694691274
#             total accurancy =  0.8053037952015953
#     when max_depth =  9
#         use  entropy
#             train accurancy =  0.8096950981314673
#             test accurancy =  0.8042059694691274
#             total accurancy =  0.8053037952015953
#         use  gini
#             train accurancy =  0.8096950981314673
#             test accurancy =  0.8042059694691274
#             total accurancy =  0.8053037952015953
#         use  infogain_ratio
#             train accurancy =  0.8096950981314673
#             test accurancy =  0.8042059694691274
#             total accurancy =  0.8053037952015953
#     when max_depth =  10
#         use  entropy
#             train accurancy =  0.8096950981314673
#             test accurancy =  0.8042059694691274
#             total accurancy =  0.8053037952015953
#         use  gini
#             train accurancy =  0.8096950981314673
#             test accurancy =  0.8042059694691274
#             total accurancy =  0.8053037952015953
#         use  infogain_ratio
#             train accurancy =  0.8096950981314673
#             test accurancy =  0.8042059694691274
#             total accurancy =  0.8053037952015953
# When min_sample_leaf =  3
#     when max_depth =  4
#         use  entropy
#             train accurancy =  0.8096950981314673
#             test accurancy =  0.8042059694691274
#             total accurancy =  0.8053037952015953
#         use  gini
#             train accurancy =  0.8096950981314673
#             test accurancy =  0.8042059694691274
#             total accurancy =  0.8053037952015953
#         use  infogain_ratio
#             train accurancy =  0.8096950981314673
#             test accurancy =  0.8042059694691274
#             total accurancy =  0.8053037952015953
#     when max_depth =  5
#         use  entropy
#             train accurancy =  0.8096950981314673
#             test accurancy =  0.8042059694691274
#             total accurancy =  0.8053037952015953
#         use  gini
#             train accurancy =  0.8096950981314673
#             test accurancy =  0.8042059694691274
#             total accurancy =  0.8053037952015953
#         use  infogain_ratio
#             train accurancy =  0.8096950981314673
#             test accurancy =  0.8042059694691274
#             total accurancy =  0.8053037952015953
#     when max_depth =  6
#         use  entropy
#             train accurancy =  0.8096950981314673
#             test accurancy =  0.8042059694691274
#             total accurancy =  0.8053037952015953
#         use  gini
#             train accurancy =  0.8096950981314673
#             test accurancy =  0.8042059694691274
#             total accurancy =  0.8053037952015953
#         use  infogain_ratio
#             train accurancy =  0.8096950981314673
#             test accurancy =  0.8042059694691274
#             total accurancy =  0.8053037952015953
#     when max_depth =  7
#         use  entropy
#             train accurancy =  0.8096950981314673
#             test accurancy =  0.8042059694691274
#             total accurancy =  0.8053037952015953
#         use  gini
#             train accurancy =  0.8096950981314673
#             test accurancy =  0.8042059694691274
#             total accurancy =  0.8053037952015953
#         use  infogain_ratio
#             train accurancy =  0.8096950981314673
#             test accurancy =  0.8042059694691274
#             total accurancy =  0.8053037952015953
#     when max_depth =  8
#         use  entropy
#             train accurancy =  0.8096950981314673
#             test accurancy =  0.8042059694691274
#             total accurancy =  0.8053037952015953
#         use  gini
#             train accurancy =  0.8096950981314673
#             test accurancy =  0.8042059694691274
#             total accurancy =  0.8053037952015953
#         use  infogain_ratio
#             train accurancy =  0.8096950981314673
#             test accurancy =  0.8042059694691274
#             total accurancy =  0.8053037952015953
#     when max_depth =  9
#         use  entropy
#             train accurancy =  0.8096950981314673
#             test accurancy =  0.8042059694691274
#             total accurancy =  0.8053037952015953
#         use  gini
#             train accurancy =  0.8096950981314673
#             test accurancy =  0.8042059694691274
#             total accurancy =  0.8053037952015953
#         use  infogain_ratio
#             train accurancy =  0.8096950981314673
#             test accurancy =  0.8042059694691274
#             total accurancy =  0.8053037952015953
#     when max_depth =  10
#         use  entropy
#             train accurancy =  0.8096950981314673
#             test accurancy =  0.8042059694691274
#             total accurancy =  0.8053037952015953
#         use  gini
#             train accurancy =  0.8096950981314673
#             test accurancy =  0.8042059694691274
#             total accurancy =  0.8053037952015953
#         use  infogain_ratio
#             train accurancy =  0.8096950981314673
#             test accurancy =  0.8042059694691274
#             total accurancy =  0.8053037952015953
# When min_sample_leaf =  4
#     when max_depth =  4
#         use  entropy
#             train accurancy =  0.8096950981314673
#             test accurancy =  0.8042059694691274
#             total accurancy =  0.8053037952015953
#         use  gini
#             train accurancy =  0.8096950981314673
#             test accurancy =  0.8042059694691274
#             total accurancy =  0.8053037952015953
#         use  infogain_ratio
#             train accurancy =  0.8096950981314673
#             test accurancy =  0.8042059694691274
#             total accurancy =  0.8053037952015953
#     when max_depth =  5
#         use  entropy
#             train accurancy =  0.8096950981314673
#             test accurancy =  0.8042059694691274
#             total accurancy =  0.8053037952015953
#         use  gini
#             train accurancy =  0.8096950981314673
#             test accurancy =  0.8042059694691274
#             total accurancy =  0.8053037952015953
#         use  infogain_ratio
#             train accurancy =  0.8096950981314673
#             test accurancy =  0.8042059694691274
#             total accurancy =  0.8053037952015953
#     when max_depth =  6
#         use  entropy
#             train accurancy =  0.8096950981314673
#             test accurancy =  0.8042059694691274
#             total accurancy =  0.8053037952015953
#         use  gini
#             train accurancy =  0.8096950981314673
#             test accurancy =  0.8042059694691274
#             total accurancy =  0.8053037952015953
#         use  infogain_ratio
#             train accurancy =  0.8096950981314673
#             test accurancy =  0.8042059694691274
#             total accurancy =  0.8053037952015953
#     when max_depth =  7
#         use  entropy
#             train accurancy =  0.8096950981314673
#             test accurancy =  0.8042059694691274
#             total accurancy =  0.8053037952015953
#         use  gini
#             train accurancy =  0.8096950981314673
#             test accurancy =  0.8042059694691274
#             total accurancy =  0.8053037952015953
#         use  infogain_ratio
#             train accurancy =  0.8096950981314673
#             test accurancy =  0.8042059694691274
#             total accurancy =  0.8053037952015953
#     when max_depth =  8
#         use  entropy
#             train accurancy =  0.8096950981314673
#             test accurancy =  0.8042059694691274
#             total accurancy =  0.8053037952015953
#         use  gini
#             train accurancy =  0.8096950981314673
#             test accurancy =  0.8042059694691274
#             total accurancy =  0.8053037952015953
#         use  infogain_ratio
#             train accurancy =  0.8096950981314673
#             test accurancy =  0.8042059694691274
#             total accurancy =  0.8053037952015953
#     when max_depth =  9
#         use  entropy
#             train accurancy =  0.8096950981314673
#             test accurancy =  0.8042059694691274
#             total accurancy =  0.8053037952015953
#         use  gini
#             train accurancy =  0.8096950981314673
#             test accurancy =  0.8042059694691274
#             total accurancy =  0.8053037952015953
#         use  infogain_ratio
#             train accurancy =  0.8096950981314673
#             test accurancy =  0.8042059694691274
#             total accurancy =  0.8053037952015953
#     when max_depth =  10
#         use  entropy
#             train accurancy =  0.8096950981314673
#             test accurancy =  0.8042059694691274
#             total accurancy =  0.8053037952015953
#         use  gini
#             train accurancy =  0.8096950981314673
#             test accurancy =  0.8042059694691274
#             total accurancy =  0.8053037952015953
#         use  infogain_ratio
#             train accurancy =  0.8096950981314673
#             test accurancy =  0.8042059694691274
#             total accurancy =  0.8053037952015953
# When min_sample_leaf =  5
#     when max_depth =  4
#         use  entropy
#             train accurancy =  0.8096950981314673
#             test accurancy =  0.8042059694691274
#             total accurancy =  0.8053037952015953
#         use  gini
#             train accurancy =  0.8096950981314673
#             test accurancy =  0.8042059694691274
#             total accurancy =  0.8053037952015953
#         use  infogain_ratio
#             train accurancy =  0.8096950981314673
#             test accurancy =  0.8042059694691274
#             total accurancy =  0.8053037952015953
#     when max_depth =  5
#         use  entropy
#             train accurancy =  0.8096950981314673
#             test accurancy =  0.8042059694691274
#             total accurancy =  0.8053037952015953
#         use  gini
#             train accurancy =  0.8096950981314673
#             test accurancy =  0.8042059694691274
#             total accurancy =  0.8053037952015953
#         use  infogain_ratio
#             train accurancy =  0.8096950981314673
#             test accurancy =  0.8042059694691274
#             total accurancy =  0.8053037952015953
#     when max_depth =  6
#         use  entropy
#             train accurancy =  0.8096950981314673
#             test accurancy =  0.8042059694691274
#             total accurancy =  0.8053037952015953
#         use  gini
#             train accurancy =  0.8096950981314673
#             test accurancy =  0.8042059694691274
#             total accurancy =  0.8053037952015953
#         use  infogain_ratio
#             train accurancy =  0.8096950981314673
#             test accurancy =  0.8042059694691274
#             total accurancy =  0.8053037952015953
#     when max_depth =  7
#         use  entropy
#             train accurancy =  0.8096950981314673
#             test accurancy =  0.8042059694691274
#             total accurancy =  0.8053037952015953
#         use  gini
#             train accurancy =  0.8096950981314673
#             test accurancy =  0.8042059694691274
#             total accurancy =  0.8053037952015953
#         use  infogain_ratio
#             train accurancy =  0.8096950981314673
#             test accurancy =  0.8042059694691274
#             total accurancy =  0.8053037952015953
#     when max_depth =  8
#         use  entropy
#             train accurancy =  0.8096950981314673
#             test accurancy =  0.8042059694691274
#             total accurancy =  0.8053037952015953
#         use  gini
#             train accurancy =  0.8096950981314673
#             test accurancy =  0.8042059694691274
#             total accurancy =  0.8053037952015953
#         use  infogain_ratio
#             train accurancy =  0.8096950981314673
#             test accurancy =  0.8042059694691274
#             total accurancy =  0.8053037952015953
#     when max_depth =  9
#         use  entropy
#             train accurancy =  0.8096950981314673
#             test accurancy =  0.8042059694691274
#             total accurancy =  0.8053037952015953
#         use  gini
#             train accurancy =  0.8096950981314673
#             test accurancy =  0.8042059694691274
#             total accurancy =  0.8053037952015953
#         use  infogain_ratio
#             train accurancy =  0.8096950981314673
#             test accurancy =  0.8042059694691274
#             total accurancy =  0.8053037952015953
#     when max_depth =  10
#         use  entropy
#             train accurancy =  0.8096950981314673
#             test accurancy =  0.8042059694691274
#             total accurancy =  0.8053037952015953
#         use  gini
#             train accurancy =  0.8096950981314673
#             test accurancy =  0.8042059694691274
#             total accurancy =  0.8053037952015953
#         use  infogain_ratio
#             train accurancy =  0.8096950981314673
#             test accurancy =  0.8042059694691274
#             total accurancy =  0.8053037952015953
# When min_sample_leaf =  6
#     when max_depth =  4
#         use  entropy
#             train accurancy =  0.8096950981314673
#             test accurancy =  0.8042059694691274
#             total accurancy =  0.8053037952015953
#         use  gini
#             train accurancy =  0.8096950981314673
#             test accurancy =  0.8042059694691274
#             total accurancy =  0.8053037952015953
#         use  infogain_ratio
#             train accurancy =  0.8096950981314673
#             test accurancy =  0.8042059694691274
#             total accurancy =  0.8053037952015953
#     when max_depth =  5
#         use  entropy
#             train accurancy =  0.8096950981314673
#             test accurancy =  0.8042059694691274
#             total accurancy =  0.8053037952015953
#         use  gini
#             train accurancy =  0.8096950981314673
#             test accurancy =  0.8042059694691274
#             total accurancy =  0.8053037952015953
#         use  infogain_ratio
#             train accurancy =  0.8096950981314673
#             test accurancy =  0.8042059694691274
#             total accurancy =  0.8053037952015953
#     when max_depth =  6
#         use  entropy
#             train accurancy =  0.8096950981314673
#             test accurancy =  0.8042059694691274
#             total accurancy =  0.8053037952015953
#         use  gini
#             train accurancy =  0.8096950981314673
#             test accurancy =  0.8042059694691274
#             total accurancy =  0.8053037952015953
#         use  infogain_ratio
#             train accurancy =  0.8096950981314673
#             test accurancy =  0.8042059694691274
#             total accurancy =  0.8053037952015953
#     when max_depth =  7
#         use  entropy
#             train accurancy =  0.8096950981314673
#             test accurancy =  0.8042059694691274
#             total accurancy =  0.8053037952015953
#         use  gini
#             train accurancy =  0.8096950981314673
#             test accurancy =  0.8042059694691274
#             total accurancy =  0.8053037952015953
#         use  infogain_ratio
#             train accurancy =  0.8096950981314673
#             test accurancy =  0.8042059694691274
#             total accurancy =  0.8053037952015953
#     when max_depth =  8
#         use  entropy
#             train accurancy =  0.8096950981314673
#             test accurancy =  0.8042059694691274
#             total accurancy =  0.8053037952015953
#         use  gini
#             train accurancy =  0.8096950981314673
#             test accurancy =  0.8042059694691274
#             total accurancy =  0.8053037952015953
#         use  infogain_ratio
#             train accurancy =  0.8096950981314673
#             test accurancy =  0.8042059694691274
#             total accurancy =  0.8053037952015953
#     when max_depth =  9
#         use  entropy
#             train accurancy =  0.8096950981314673
#             test accurancy =  0.8042059694691274
#             total accurancy =  0.8053037952015953
#         use  gini
#             train accurancy =  0.8096950981314673
#             test accurancy =  0.8042059694691274
#             total accurancy =  0.8053037952015953
#         use  infogain_ratio
#             train accurancy =  0.8096950981314673
#             test accurancy =  0.8042059694691274
#             total accurancy =  0.8053037952015953
#     when max_depth =  10
#         use  entropy
#             train accurancy =  0.8096950981314673
#             test accurancy =  0.8042059694691274
#             total accurancy =  0.8053037952015953
#         use  gini
#             train accurancy =  0.8096950981314673
#             test accurancy =  0.8042059694691274
#             total accurancy =  0.8053037952015953
#         use  infogain_ratio
#             train accurancy =  0.8096950981314673
#             test accurancy =  0.8042059694691274
#             total accurancy =  0.8053037952015953
# When min_sample_leaf =  7
#     when max_depth =  4
#         use  entropy
#             train accurancy =  0.8096950981314673
#             test accurancy =  0.8042059694691274
#             total accurancy =  0.8053037952015953
#         use  gini
#             train accurancy =  0.8096950981314673
#             test accurancy =  0.8042059694691274
#             total accurancy =  0.8053037952015953
#         use  infogain_ratio
#             train accurancy =  0.8096950981314673
#             test accurancy =  0.8042059694691274
#             total accurancy =  0.8053037952015953
#     when max_depth =  5
#         use  entropy
#             train accurancy =  0.8096950981314673
#             test accurancy =  0.8042059694691274
#             total accurancy =  0.8053037952015953
#         use  gini
#             train accurancy =  0.8096950981314673
#             test accurancy =  0.8042059694691274
#             total accurancy =  0.8053037952015953
#         use  infogain_ratio
#             train accurancy =  0.8096950981314673
#             test accurancy =  0.8042059694691274
#             total accurancy =  0.8053037952015953
#     when max_depth =  6
#         use  entropy
#             train accurancy =  0.8096950981314673
#             test accurancy =  0.8042059694691274
#             total accurancy =  0.8053037952015953
#         use  gini
#             train accurancy =  0.8096950981314673
#             test accurancy =  0.8042059694691274
#             total accurancy =  0.8053037952015953
#         use  infogain_ratio
#             train accurancy =  0.8096950981314673
#             test accurancy =  0.8042059694691274
#             total accurancy =  0.8053037952015953
#     when max_depth =  7
#         use  entropy
#             train accurancy =  0.8096950981314673
#             test accurancy =  0.8042059694691274
#             total accurancy =  0.8053037952015953
#         use  gini
#             train accurancy =  0.8096950981314673
#             test accurancy =  0.8042059694691274
#             total accurancy =  0.8053037952015953
#         use  infogain_ratio
#             train accurancy =  0.8096950981314673
#             test accurancy =  0.8042059694691274
#             total accurancy =  0.8053037952015953
#     when max_depth =  8
#         use  entropy
#             train accurancy =  0.8096950981314673
#             test accurancy =  0.8042059694691274
#             total accurancy =  0.8053037952015953
#         use  gini
#             train accurancy =  0.8096950981314673
#             test accurancy =  0.8042059694691274
#             total accurancy =  0.8053037952015953
#         use  infogain_ratio
#             train accurancy =  0.8096950981314673
#             test accurancy =  0.8042059694691274
#             total accurancy =  0.8053037952015953
#     when max_depth =  9
#         use  entropy
#             train accurancy =  0.8096950981314673
#             test accurancy =  0.8042059694691274
#             total accurancy =  0.8053037952015953
#         use  gini
#             train accurancy =  0.8096950981314673
#             test accurancy =  0.8042059694691274
#             total accurancy =  0.8053037952015953
#         use  infogain_ratio
#             train accurancy =  0.8096950981314673
#             test accurancy =  0.8042059694691274
#             total accurancy =  0.8053037952015953
#     when max_depth =  10
#         use  entropy
#             train accurancy =  0.8096950981314673
#             test accurancy =  0.8042059694691274
#             total accurancy =  0.8053037952015953
#         use  gini
#             train accurancy =  0.8096950981314673
#             test accurancy =  0.8042059694691274
#             total accurancy =  0.8053037952015953
#         use  infogain_ratio
#             train accurancy =  0.8096950981314673
#             test accurancy =  0.8042059694691274
#             total accurancy =  0.8053037952015953
# When min_sample_leaf =  8
#     when max_depth =  4
#         use  entropy
#             train accurancy =  0.8096950981314673
#             test accurancy =  0.8042059694691274
#             total accurancy =  0.8053037952015953
#         use  gini
#             train accurancy =  0.8096950981314673
#             test accurancy =  0.8042059694691274
#             total accurancy =  0.8053037952015953
#         use  infogain_ratio
#             train accurancy =  0.8096950981314673
#             test accurancy =  0.8042059694691274
#             total accurancy =  0.8053037952015953
#     when max_depth =  5
#         use  entropy
#             train accurancy =  0.8096950981314673
#             test accurancy =  0.8042059694691274
#             total accurancy =  0.8053037952015953
#         use  gini
#             train accurancy =  0.8096950981314673
#             test accurancy =  0.8042059694691274
#             total accurancy =  0.8053037952015953
#         use  infogain_ratio
#             train accurancy =  0.8096950981314673
#             test accurancy =  0.8042059694691274
#             total accurancy =  0.8053037952015953
#     when max_depth =  6
#         use  entropy
#             train accurancy =  0.8096950981314673
#             test accurancy =  0.8042059694691274
#             total accurancy =  0.8053037952015953
#         use  gini
#             train accurancy =  0.8096950981314673
#             test accurancy =  0.8042059694691274
#             total accurancy =  0.8053037952015953
#         use  infogain_ratio
#             train accurancy =  0.8096950981314673
#             test accurancy =  0.8042059694691274
#             total accurancy =  0.8053037952015953
#     when max_depth =  7
#         use  entropy
#             train accurancy =  0.8096950981314673
#             test accurancy =  0.8042059694691274
#             total accurancy =  0.8053037952015953
#         use  gini
#             train accurancy =  0.8096950981314673
#             test accurancy =  0.8042059694691274
#             total accurancy =  0.8053037952015953
#         use  infogain_ratio
#             train accurancy =  0.8096950981314673
#             test accurancy =  0.8042059694691274
#             total accurancy =  0.8053037952015953
#     when max_depth =  8
#         use  entropy
#             train accurancy =  0.8096950981314673
#             test accurancy =  0.8042059694691274
#             total accurancy =  0.8053037952015953
#         use  gini
#             train accurancy =  0.8096950981314673
#             test accurancy =  0.8042059694691274
#             total accurancy =  0.8053037952015953
#         use  infogain_ratio
#             train accurancy =  0.8096950981314673
#             test accurancy =  0.8042059694691274
#             total accurancy =  0.8053037952015953
#     when max_depth =  9
#         use  entropy
#             train accurancy =  0.8096950981314673
#             test accurancy =  0.8042059694691274
#             total accurancy =  0.8053037952015953
#         use  gini
#             train accurancy =  0.8096950981314673
#             test accurancy =  0.8042059694691274
#             total accurancy =  0.8053037952015953
#         use  infogain_ratio
#             train accurancy =  0.8096950981314673
#             test accurancy =  0.8042059694691274
#             total accurancy =  0.8053037952015953
#     when max_depth =  10
#         use  entropy
#             train accurancy =  0.8096950981314673
#             test accurancy =  0.8042059694691274
#             total accurancy =  0.8053037952015953
#         use  gini
#             train accurancy =  0.8096950981314673
#             test accurancy =  0.8042059694691274
#             total accurancy =  0.8053037952015953
#         use  infogain_ratio
#             train accurancy =  0.8096950981314673
#             test accurancy =  0.8042059694691274
#             total accurancy =  0.8053037952015953
# When min_sample_leaf =  9
#     when max_depth =  4
#         use  entropy
#             train accurancy =  0.8096950981314673
#             test accurancy =  0.8042059694691274
#             total accurancy =  0.8053037952015953
#         use  gini
#             train accurancy =  0.8096950981314673
#             test accurancy =  0.8042059694691274
#             total accurancy =  0.8053037952015953
#         use  infogain_ratio
#             train accurancy =  0.8096950981314673
#             test accurancy =  0.8042059694691274
#             total accurancy =  0.8053037952015953
#     when max_depth =  5
#         use  entropy
#             train accurancy =  0.8096950981314673
#             test accurancy =  0.8042059694691274
#             total accurancy =  0.8053037952015953
#         use  gini
#             train accurancy =  0.8096950981314673
#             test accurancy =  0.8042059694691274
#             total accurancy =  0.8053037952015953
#         use  infogain_ratio
#             train accurancy =  0.8096950981314673
#             test accurancy =  0.8042059694691274
#             total accurancy =  0.8053037952015953
#     when max_depth =  6
#         use  entropy
#             train accurancy =  0.8096950981314673
#             test accurancy =  0.8042059694691274
#             total accurancy =  0.8053037952015953
#         use  gini
#             train accurancy =  0.8096950981314673
#             test accurancy =  0.8042059694691274
#             total accurancy =  0.8053037952015953
#         use  infogain_ratio
#             train accurancy =  0.8096950981314673
#             test accurancy =  0.8042059694691274
#             total accurancy =  0.8053037952015953
#     when max_depth =  7
#         use  entropy
#             train accurancy =  0.8096950981314673
#             test accurancy =  0.8042059694691274
#             total accurancy =  0.8053037952015953
#         use  gini
#             train accurancy =  0.8096950981314673
#             test accurancy =  0.8042059694691274
#             total accurancy =  0.8053037952015953
#         use  infogain_ratio
#             train accurancy =  0.8096950981314673
#             test accurancy =  0.8042059694691274
#             total accurancy =  0.8053037952015953
#     when max_depth =  8
#         use  entropy
#             train accurancy =  0.8096950981314673
#             test accurancy =  0.8042059694691274
#             total accurancy =  0.8053037952015953
#         use  gini
#             train accurancy =  0.8096950981314673
#             test accurancy =  0.8042059694691274
#             total accurancy =  0.8053037952015953
#         use  infogain_ratio
#             train accurancy =  0.8096950981314673
#             test accurancy =  0.8042059694691274
#             total accurancy =  0.8053037952015953
#     when max_depth =  9
#         use  entropy
#             train accurancy =  0.8096950981314673
#             test accurancy =  0.8042059694691274
#             total accurancy =  0.8053037952015953
#         use  gini
#             train accurancy =  0.8096950981314673
#             test accurancy =  0.8042059694691274
#             total accurancy =  0.8053037952015953
#         use  infogain_ratio
#             train accurancy =  0.8096950981314673
#             test accurancy =  0.8042059694691274
#             total accurancy =  0.8053037952015953
#     when max_depth =  10
#         use  entropy
#             train accurancy =  0.8096950981314673
#             test accurancy =  0.8042059694691274
#             total accurancy =  0.8053037952015953
#         use  gini
#             train accurancy =  0.8096950981314673
#             test accurancy =  0.8042059694691274
#             total accurancy =  0.8053037952015953
#         use  infogain_ratio
#             train accurancy =  0.8096950981314673
#             test accurancy =  0.8042059694691274
#             total accurancy =  0.8053037952015953
# When min_sample_leaf =  10
#     when max_depth =  4
#         use  entropy
#             train accurancy =  0.8096950981314673
#             test accurancy =  0.8042059694691274
#             total accurancy =  0.8053037952015953
#         use  gini
#             train accurancy =  0.8096950981314673
#             test accurancy =  0.8042059694691274
#             total accurancy =  0.8053037952015953
#         use  infogain_ratio
#             train accurancy =  0.8096950981314673
#             test accurancy =  0.8042059694691274
#             total accurancy =  0.8053037952015953
#     when max_depth =  5
#         use  entropy
#             train accurancy =  0.8096950981314673
#             test accurancy =  0.8042059694691274
#             total accurancy =  0.8053037952015953
#         use  gini
#             train accurancy =  0.8096950981314673
#             test accurancy =  0.8042059694691274
#             total accurancy =  0.8053037952015953
#         use  infogain_ratio
#             train accurancy =  0.8096950981314673
#             test accurancy =  0.8042059694691274
#             total accurancy =  0.8053037952015953
#     when max_depth =  6
#         use  entropy
#             train accurancy =  0.8096950981314673
#             test accurancy =  0.8042059694691274
#             total accurancy =  0.8053037952015953
#         use  gini
#             train accurancy =  0.8096950981314673
#             test accurancy =  0.8042059694691274
#             total accurancy =  0.8053037952015953
#         use  infogain_ratio
#             train accurancy =  0.8096950981314673
#             test accurancy =  0.8042059694691274
#             total accurancy =  0.8053037952015953
#     when max_depth =  7
#         use  entropy
#             train accurancy =  0.8096950981314673
#             test accurancy =  0.8042059694691274
#             total accurancy =  0.8053037952015953
#         use  gini
#             train accurancy =  0.8096950981314673
#             test accurancy =  0.8042059694691274
#             total accurancy =  0.8053037952015953
#         use  infogain_ratio
#             train accurancy =  0.8096950981314673
#             test accurancy =  0.8042059694691274
#             total accurancy =  0.8053037952015953
#     when max_depth =  8
#         use  entropy
#             train accurancy =  0.8096950981314673
#             test accurancy =  0.8042059694691274
#             total accurancy =  0.8053037952015953
#         use  gini
#             train accurancy =  0.8096950981314673
#             test accurancy =  0.8042059694691274
#             total accurancy =  0.8053037952015953
#         use  infogain_ratio
#             train accurancy =  0.8096950981314673
#             test accurancy =  0.8042059694691274
#             total accurancy =  0.8053037952015953
#     when max_depth =  9
#         use  entropy
#             train accurancy =  0.8096950981314673
#             test accurancy =  0.8042059694691274
#             total accurancy =  0.8053037952015953
#         use  gini
#             train accurancy =  0.8096950981314673
#             test accurancy =  0.8042059694691274
#             total accurancy =  0.8053037952015953
#         use  infogain_ratio
#             train accurancy =  0.8096950981314673
#             test accurancy =  0.8042059694691274
#             total accurancy =  0.8053037952015953
#     when max_depth =  10
#         use  entropy
#             train accurancy =  0.8096950981314673
#             test accurancy =  0.8042059694691274
#             total accurancy =  0.8053037952015953
#         use  gini
#             train accurancy =  0.8096950981314673
#             test accurancy =  0.8042059694691274
#             total accurancy =  0.8053037952015953
#         use  infogain_ratio
#             train accurancy =  0.8096950981314673
#             test accurancy =  0.8042059694691274
#             total accurancy =  0.8053037952015953
# The best decision tree using adaboost is:
# best accurancy =  0.8053037952015953
# best min leaf =  2
# best depth =  4
# best criterion =  entropy

# %%
# report the accuracy on test set
# begin answer
base = DecisionTree(criterion=best_method, max_depth=best_depth, min_samples_leaf=best_min_leaf, sample_feature=False)
ada = Adaboost(base_learner=base, n_estimator=50, seed=2020)
# end answer
ada.fit(X, y)
print("Accuracy on train set: {}".format(accuracy(y, ada.predict(X))))
print("Accuracy on test set: {}".format(accuracy(y_test, ada.predict(X_test))))
# Out:
# Accuracy on train set: 0.8739255014326648
# Accuracy on test set: 0.7862595419847328
